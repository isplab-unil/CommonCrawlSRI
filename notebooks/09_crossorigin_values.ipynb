# %% [markdown]
# # 09 Crossorigin values

# %%
import re
from glob import iglob
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the CSV files

# %%
for file in iglob('../data/sri/*/reports/09_crossorigin_values.csv/*.csv', recursive=True):
    with open(file, 'r') as csv:
        data = pd.read_csv(file)

data
# Out:
#                                                 value    number  percentage
# 0                                           anonymous  33926500       97.85
# 1                                                 NaN    734985        2.12
# 2                                       anonymou\r\ns      6420        0.02
# 3                                     use-credentials      4941        0.01
# 4                                          andonymous       283        0.00
# 5                                   \\\anonymous\\\""        27        0.00
# 6                                          >anonymous        26        0.00
# 7                                          /anonymous         8        0.00
# 8                                                true         4        0.00
# 9                                         an\tonymous         3        0.00
# 10                     http://ingreso.guardiacivil.es         3        0.00
# ...

# %% [markdown]
# ## Prepare the data

# %%
data['number'].sum()
# Out:
# 34673217
